# %%
from xgboost import XGBRegressor
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error,mean_absolute_error
from math import sqrt
from sklearn.model_selection import train_test_split
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})
pd.options.mode.chained_assignment = None

# %%
df=pd.read_csv('DataClean1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        Date  Temp
# 0           0  1981-01-01  20.7
# 1           1  1981-01-02  17.9
# 2           2  1981-01-03  18.8
# 3           3  1981-01-04  14.6
# 4           4  1981-01-05  15.8

# %%
df.rename(columns={'Unnamed: 0':'index'},inplace=True)

# %%
df.head()
# Out:
#    index        Date  Temp
# 0      0  1981-01-01  20.7
# 1      1  1981-01-02  17.9
# 2      2  1981-01-03  18.8
# 3      3  1981-01-04  14.6
# 4      4  1981-01-05  15.8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3650 entries, 0 to 3649
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   index   3650 non-null   int64
#  1   Date    3650 non-null   object
#  2   Temp    3650 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 85.7+ KB

# %%
X=df[['index']]
y=df[['Temp']]

# %%
 #Break off validation set from training data
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2,
                                                                random_state=0)

# %%
X_train.shape
# Out:
# (2920, 1)

# %%
def get_mae(n_estimators, X_train, X_test, y_train, y_test):
    model = XGBRegressor(objective='reg:squarederror',n_estimators= n_estimators)
    model.fit(X_train, y_train)
    preds_val = model.predict(X_test)
    mae = mean_squared_error(y_test, preds_val)
    return(mae)

# %%
# compare MAE with differing values of max_leaf_nodes
for n_estimators in range(50,1000,25):
    my_mae = get_mae(n_estimators, X_train, X_test, y_train, y_test)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %.2f" %(n_estimators, my_mae))
# Out:
# Max leaf nodes: 50  		 Mean Absolute Error:  6.28
# Max leaf nodes: 75  		 Mean Absolute Error:  6.16
# Max leaf nodes: 100  		 Mean Absolute Error:  6.15
# Max leaf nodes: 125  		 Mean Absolute Error:  6.21
# Max leaf nodes: 150  		 Mean Absolute Error:  6.18
# Max leaf nodes: 175  		 Mean Absolute Error:  6.22
# Max leaf nodes: 200  		 Mean Absolute Error:  6.23
# Max leaf nodes: 225  		 Mean Absolute Error:  6.28
# Max leaf nodes: 250  		 Mean Absolute Error:  6.36
# Max leaf nodes: 275  		 Mean Absolute Error:  6.41
# Max leaf nodes: 300  		 Mean Absolute Error:  6.40
# Max leaf nodes: 325  		 Mean Absolute Error:  6.42
# Max leaf nodes: 350  		 Mean Absolute Error:  6.47
# Max leaf nodes: 375  		 Mean Absolute Error:  6.51
# Max leaf nodes: 400  		 Mean Absolute Error:  6.59
# Max leaf nodes: 425  		 Mean Absolute Error:  6.65
# Max leaf nodes: 450  		 Mean Absolute Error:  6.68
# Max leaf nodes: 475  		 Mean Absolute Error:  6.71
# Max leaf nodes: 500  		 Mean Absolute Error:  6.73
# Max leaf nodes: 525  		 Mean Absolute Error:  6.75
# Max leaf nodes: 550  		 Mean Absolute Error:  6.82
# Max leaf nodes: 575  		 Mean Absolute Error:  6.86
# Max leaf nodes: 600  		 Mean Absolute Error:  6.89
# Max leaf nodes: 625  		 Mean Absolute Error:  6.96
# Max leaf nodes: 650  		 Mean Absolute Error:  6.99
# Max leaf nodes: 675  		 Mean Absolute Error:  7.01
# Max leaf nodes: 700  		 Mean Absolute Error:  7.06
# Max leaf nodes: 725  		 Mean Absolute Error:  7.09
# Max leaf nodes: 750  		 Mean Absolute Error:  7.14
# Max leaf nodes: 775  		 Mean Absolute Error:  7.17
# Max leaf nodes: 800  		 Mean Absolute Error:  7.19
# Max leaf nodes: 825  		 Mean Absolute Error:  7.22
# Max leaf nodes: 850  		 Mean Absolute Error:  7.23
# Max leaf nodes: 875  		 Mean Absolute Error:  7.27
# Max leaf nodes: 900  		 Mean Absolute Error:  7.29
# Max leaf nodes: 925  		 Mean Absolute Error:  7.32
# Max leaf nodes: 950  		 Mean Absolute Error:  7.36
# Max leaf nodes: 975  		 Mean Absolute Error:  7.39

# %%
model = XGBRegressor(objective='reg:squarederror', n_estimators=100)
model=model.fit(X_train, y_train)  
predict = model.predict(X_test)
# Calculate MAE
rmse=sqrt(mean_squared_error(X_test, predict))# Uncomment to print MAE
print("Mean Squered Error:" , rmse)
# Out:
# Mean Squered Error: 2072.9005717673176

# %%
plt.plot(y_test.values, label='Original')
plt.plot(predict, color='red', label='XGboost')
plt.legend()
