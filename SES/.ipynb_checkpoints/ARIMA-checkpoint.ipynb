# %%
import pandas as pd
import numpy as np
import datetime as dt
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import acf
plt.rcParams.update({'figure.figsize':(9,3), 'figure.dpi':120})
pd.options.mode.chained_assignment = None

# %%
dataset=pd.read_excel('DataSet1.xlsx')

# %%
dataset.head()
# Out:
#        "Date","Temp"
# 0  "1981-01-01",20.7
# 1  "1981-01-02",17.9
# 2  "1981-01-03",18.8
# 3  "1981-01-04",14.6
# 4  "1981-01-05",15.8

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3650 entries, 0 to 3649
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   "Date","Temp"  3650 non-null   object
# dtypes: object(1)
# memory usage: 28.6+ KB

# %%
new = dataset['"Date","Temp"'].str.split(",", n = 1, expand = True)

# %%
dataset['Date']=new[0]
dataset['Temp']=new[1]

# %%
dataset['Temp'].iloc[1859]
# Out:
# '11.6'

# %%
dataset['Date'].iloc[1859]
# Out:
# '"1986-02-04"'

# %%
temp=dataset['Temp'].iloc[1859]
dat=dataset['Date'].iloc[1859]

# %%
print(temp)
# Out:
# 11.6

# %%
dataset['Temp'].iloc[1859]=temp
dataset['Date'].iloc[1859]=dat

# %%
dataset.loc[1859]
# Out:
# Date    "1986-02-04"
# Temp            11.6
# Name: 1859, dtype: object

# %%
dataset['Temp']=pd.to_numeric(dataset['Temp'])

# %%
dataset.head()
# Out:
#            Date  Temp
# 0  "1981-01-01"  20.7
# 1  "1981-01-02"  17.9
# 2  "1981-01-03"  18.8
# 3  "1981-01-04"  14.6
# 4  "1981-01-05"  15.8

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3650 entries, 0 to 3649
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3650 non-null   object
#  1   Temp    3650 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 57.2+ KB

# %%
dataset.head()
# Out:
#            Date  Temp
# 0  "1981-01-01"  20.7
# 1  "1981-01-02"  17.9
# 2  "1981-01-03"  18.8
# 3  "1981-01-04"  14.6
# 4  "1981-01-05"  15.8

# %%
dataset.plot()

# %%
dataset['Date']=dataset['Date'].str.replace('\"','')

# %%
dataset.head()
# Out:
#          Date  Temp
# 0  1981-01-01  20.7
# 1  1981-01-02  17.9
# 2  1981-01-03  18.8
# 3  1981-01-04  14.6
# 4  1981-01-05  15.8

# %%
dataset.to_csv('your_csv.csv', encoding='utf-8')

# %%
# Import data
df = pd.read_csv('your_csv.csv', names=['value'], header=0)

# %%
df.head()
# Out:
#               value
# 0 1981-01-01   20.7
# 1 1981-01-02   17.9
# 2 1981-01-03   18.8
# 3 1981-01-04   14.6
# 4 1981-01-05   15.8

# %%
train = df[:-30].value
test = df[-30:].value

# %%
model = pm.auto_arima(train, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=17233.672, Time=0.47 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=28187.558, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=17519.951, Time=0.21 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=24309.376, Time=0.29 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=16712.274, Time=1.40 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=17415.635, Time=0.38 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=16658.561, Time=1.24 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=17171.937, Time=0.45 sec
#  ARIMA(3,0,2)(0,0,0)[0]             : AIC=16713.342, Time=2.60 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=16661.930, Time=1.61 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=16645.808, Time=5.21 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=16700.510, Time=4.01 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=16981.966, Time=1.28 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=16647.805, Time=6.66 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=17115.594, Time=0.80 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=16649.640, Time=4.35 sec
#
# Best model:  ARIMA(3,0,1)(0,0,0)[0] intercept
# Total fit time: 31.034 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3620
# Model:               SARIMAX(3, 0, 1)   Log Likelihood               -8316.904
# Date:                Mon, 23 Aug 2021   AIC                          16645.808
# Time:                        20:12:44   BIC                          16682.973
# Sample:                             0   HQIC                         16659.049
#                                - 3620
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0568      0.018      3.126      0.002       0.021       0.092
# ar.L1          1.4824      0.019     79.851      0.000       1.446       1.519
# ar.L2         -0.6198      0.027    -23.290      0.000      -0.672      -0.568
# ar.L3          0.1324      0.018      7.470      0.000       0.098       0.167
# ma.L1         -0.8918      0.012    -75.459      0.000      -0.915      -0.869
# sigma2         5.7929      0.128     45.139      0.000       5.541       6.044
# ===================================================================================
# Ljung-Box (Q):                       46.86   Jarque-Bera (JB):                16.65
# Prob(Q):                              0.21   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.86   Skew:                             0.09
# Prob(H) (two-sided):                  0.01   Kurtosis:                         3.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# 1,1,2 ARIMA Model
model = ARIMA(train, order=(3,0,1))

model = model.fit(disp=0)
print(model.summary())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:213: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   warnings.warn('An unsupported index was provided and will be'
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:                  value   No. Observations:                 3620
# Model:                     ARMA(3, 1)   Log Likelihood               -8316.904
# Method:                       css-mle   S.D. of innovations              2.407
# Date:                Mon, 23 Aug 2021   AIC                          16645.808
# Time:                        20:12:56   BIC                          16682.973
# Sample:                             0   HQIC                         16659.049
#
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          11.4102      0.843     13.535      0.000       9.758      13.063
# ar.L1.value     1.4824      0.019     78.213      0.000       1.445       1.520
# ar.L2.value    -0.6198      0.028    -22.190      0.000      -0.675      -0.565
# ar.L3.value     0.1324      0.017      7.581      0.000       0.098       0.167
# ma.L1.value    -0.8918      0.010    -87.104      0.000      -0.912      -0.872
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0078           -0.0000j            1.0078           -0.0000
# AR.2            1.8362           -2.0300j            2.7373           -0.1330
# AR.3            1.8362           +2.0300j            2.7373            0.1330
# MA.1            1.1213           +0.0000j            1.1213            0.0000
# -----------------------------------------------------------------------------

# %%
# Plot residual errors
residuals = pd.DataFrame(model.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %%
# Actual vs Fitted
#model.plot_predict(dynamic=False,alpha=0.05)
start= len(test)
end = len(train)+len(test)-1
print(start)
print(end)
model.plot_predict(start=3500,end=3649,dynamic=False,alpha=0.05)
plt.figure(figsize=(15,5))
plt.show()
# Out:
# 30
# 3649
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:580: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   warnings.warn('No supported index is available.'
